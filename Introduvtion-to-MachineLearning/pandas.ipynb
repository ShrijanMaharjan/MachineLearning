# %% [markdown]
# <a href="https://colab.research.google.com/github/ShrijanMaharjan/MachineLearning/blob/main/Introduvtion-to-MachineLearning/pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Pandas 🐼
# Data Preprocessing in Machine learning using Pandas
# Data Preprocessing is required tasks for cleaning the data and making it suitable for a machine learning model which also increases the accuracy and efficiency of a machine learning model.
#
# Pandas is an open source Python package that is most widely used for data science/data analysis and machine learning tasks. It is built on top of another package named Numpy, which provides support for multi-dimensional arrays. Preprocessing is the process of doing a pre-analysis of data, in order to transform them into a standard and normalized format.
#
# Preprocessing involves the following aspects:
# - missing values
# - data standardization
# - data normalization
# - data minning

# %%
import pandas as pd
data = {
    "cars": ["bmw","honda","suzuki","byd"],
    "models":["2007","2008","2015","2024"],
    "passen":["4","6","6","5"]
}
data
# Out:
# {'cars': ['bmw', 'honda', 'suzuki', 'byd'],
#  'models': ['2007', '2008', '2015', '2024'],
#  'passen': ['4', '6', '6', '5']}

# %%
# convert the data directory to dataframe
df = pd.DataFrame(data)
df
# Out:
#      cars models passen
# 0     bmw   2007      4
# 1   honda   2008      6
# 2  suzuki   2015      6
# 3     byd   2024      5

# %%
df.to_csv("/content/drive/MyDrive/Colab Notebooks/car/car_data.csv")

# %%
df=pd.read_csv("/content/drive/MyDrive/Colab Notebooks/car/car_data.csv")
df
# Out:
#    Unnamed: 0    cars  models  passen
# 0           0     bmw    2007       4
# 1           1   honda    2008       6
# 2           2  suzuki    2015       6
# 3           3     byd    2024       5

# %%
#create a dataframe with two features calories and duration
datas = {
    "calories" : ["420","500","390"],
    "duration" : ["50","60","45"]
}
datas
# Out:
# {'calories': ['420', '500', '390'], 'duration': ['50', '60', '45']}

# %%
df= pd.DataFrame(datas)
df
# Out:
#   calories duration
# 0      420       50
# 1      500       60
# 2      390       45

# %%
print(df.loc[[0,1]])
# Out:
#   calories duration
# 0      420       50
# 1      500       60

# %%
data = {
    "calories" : ["420","500","390"],
    "duration" : ["50","60","45"]
}
df = pd.DataFrame(data, index = ["day1","day2","day3"])
df
# Out:
#      calories duration
# day1      420       50
# day2      500       60
# day3      390       45

# %%
print(df.loc[["day1","day2"]])
# Out:
#      calories duration
# day1      420       50
# day2      500       60

# %% [markdown]
# # Data cleaning with Pandas
# Bad data can be
# - empty cells
# - wrong data
# - duplicates
# - data in wrong format

# %%
df = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/car/dataset(1).csv")
df.head(5)
# Out:
#    Duration  Date        Pulse  Maxpulse  Calories  Unnamed: 5
# 0         0    60  2020/12/01'       110       130       409.1
# 1         1    60  2020/12/02'       117       145       479.0
# 2         2    60  2020/12/03'       103       135       340.0
# 3         3    45  2020/12/04'       109       175       282.4
# 4         4    45  2020/12/05'       117       148       406.0

# %%
df['Pulse'] = df['Pulse'].replace(" ' "," ",regex = True)
df.head(5)
# Out:
#    Duration  Date       Pulse  Maxpulse  Calories  Unnamed: 5
# 0         0    60  2020/12/01       110       130       409.1
# 1         1    60  2020/12/02       117       145       479.0
# 2         2    60  2020/12/03       103       135       340.0
# 3         3    45  2020/12/04       109       175       282.4
# 4         4    45  2020/12/05       117       148       406.0
